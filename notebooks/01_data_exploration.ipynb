# %%
import pandas as pd


file_path = r'C:\Users\ahmad\Desktop\hackathon\data\raw\api_data_aadhar_biometric_0_500000.csv.xlsx'
# Load datasets
df_overall = pd.read_excel(file_path, engine='openpyxl')
df_state = pd.read_excel(file_path, engine='openpyxl')

# CRITICAL: Document everything
print(df_overall.shape)
print(df_overall.columns)
print(df_overall.info())
print(df_overall.describe())
print(df_overall.head(20))

# Check for nulls, duplicates, data types
print(df_overall.isnull().sum())
print(df_overall.duplicated().sum())
# Out:
# (500000, 6)
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          500000 non-null  datetime64[ns]
#  1   state         500000 non-null  object
#  2   district      500000 non-null  object
#  3   pincode       500000 non-null  int64
#  4   bio_age_5_17  500000 non-null  int64
#  5   bio_age_17_   500000 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 22.9+ MB
# None
#                                 date        pincode   bio_age_5_17  \
# count                         500000  500000.000000  500000.000000
# mean   2025-08-12 03:50:25.382400256  522548.232572      46.991398
# min              2025-03-01 00:00:00  110001.000000       0.000000
# ...

# %%
# Create cleaning pipeline
def clean_data(df):
    df_clean = df.copy()
    
    # 1. Handle missing values
    # Document your strategy: impute, drop, or flag?
    
    # 2. Fix data types
    # Convert dates, ensure numeric columns are numeric
    
    # 3. Remove duplicates
    
    # 4. Handle outliers
    # Use IQR method or domain knowledge
    
    # 5. Standardize categorical values
    # State names, gender codes, etc.
    
    # 6. Create derived features
    # enrollment_rate, update_frequency, time_features
    
    return df_clean

df_overall_clean = clean_data(df_overall)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 24
#       5     # 1. Handle missing values
#       6     # Document your strategy: impute, drop, or flag?
#       7
#    (...)
#      19     # 6. Create derived features
#      20     # enrollment_rate, update_frequency, time_features
#      22     return df_clean
# ---> 24 df_overall_clean = clean_data(df_overall)
#
# NameError: name 'df_overall' is not defined
